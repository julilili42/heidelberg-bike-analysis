# %%
import os
import folium
import matplotlib as plt
import matplotlib.colors as mcolors
import seaborn as sns
import polars as pl

# %%
# load the accident data
acc_files = os.listdir(f'../../data/processed/accidents/')
acc_frames = [pl.read_csv(f'../../data/processed/accidents/{file}') for file in acc_files]

# %%
# get a view of how the data looks like
for frame in acc_frames:
    display(frame.head(1))
# Out:
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬───────────────┬──────────┬──────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX       ┆ LINREFY  ┆ latitude ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---           ┆ ---      ┆ ---      ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64           ┆ f64      ┆ f64      ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪═══════════════╪══════════╪══════════╪═══════════╡
# │ 1     ┆ 0      ┆ 57       ┆ 25           ┆ … ┆ 579075.960927 ┆ 6.0235e6 ┆ 54.35346 ┆ 10.216714 │
# └───────┴────────┴──────────┴──────────────┴───┴───────────────┴──────────┴──────────┴───────────┘
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬─────────────┬──────────┬──────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX     ┆ LINREFY  ┆ latitude ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---         ┆ ---      ┆ ---      ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64         ┆ f64      ┆ f64      ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪═════════════╪══════════╪══════════╪═══════════╡
# │ 1     ┆ 0      ┆ 55       ┆ 12           ┆ … ┆ 605079.4229 ┆ 6.0018e6 ┆ 54.15315 ┆ 10.609031 │
# └───────┴────────┴──────────┴──────────────┴───┴─────────────┴──────────┴──────────┴───────────┘
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬─────────────┬──────────┬───────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX     ┆ LINREFY  ┆ latitude  ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---         ┆ ---      ┆ ---       ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64         ┆ f64      ┆ f64       ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪═════════════╪══════════╪═══════════╪═══════════╡
# │ 1     ┆ 0      ┆ 2        ┆ 0            ┆ … ┆ 574751.5619 ┆ 6.0183e6 ┆ 54.306951 ┆ 10.148875 │
# └───────┴────────┴──────────┴──────────────┴───┴─────────────┴──────────┴───────────┴───────────┘
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬─────────────┬──────────┬──────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX     ┆ LINREFY  ┆ latitude ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---         ┆ ---      ┆ ---      ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64         ┆ f64      ┆ f64      ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪═════════════╪══════════╪══════════╪═══════════╡
# │ 1     ┆ 0      ┆ 59       ┆ 44           ┆ … ┆ 525162.3763 ┆ 6.0455e6 ┆ 54.55638 ┆ 9.389076  │
# └───────┴────────┴──────────┴──────────────┴───┴─────────────┴──────────┴──────────┴───────────┘
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬────────────┬──────────┬───────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX    ┆ LINREFY  ┆ latitude  ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---        ┆ ---      ┆ ---       ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64        ┆ f64      ┆ f64       ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪════════════╪══════════╪═══════════╪═══════════╡
# │ 1     ┆ 0      ┆ 3        ┆ 0            ┆ … ┆ 612054.342 ┆ 5.9696e6 ┆ 53.863081 ┆ 10.70395  │
# └───────┴────────┴──────────┴──────────────┴───┴────────────┴──────────┴───────────┴───────────┘
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬───────────────┬──────────┬───────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX       ┆ LINREFY  ┆ latitude  ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---           ┆ ---      ┆ ---       ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64           ┆ f64      ┆ f64       ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪═══════════════╪══════════╪═══════════╪═══════════╡
# │ 1     ┆ 0      ┆ 54       ┆ 165          ┆ … ┆ 483995.394384 ┆ 6.0691e6 ┆ 54.768787 ┆ 8.751233  │
# └───────┴────────┴──────────┴──────────────┴───┴───────────────┴──────────┴───────────┴───────────┘
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬────────────┬──────────┬───────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX    ┆ LINREFY  ┆ latitude  ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---        ┆ ---      ┆ ---       ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64        ┆ f64      ┆ f64       ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪════════════╪══════════╪═══════════╪═══════════╡
# │ 1     ┆ 0      ┆ 54       ┆ 84           ┆ … ┆ 506085.644 ┆ 6.0351e6 ┆ 54.463396 ┆ 9.093886  │
# └───────┴────────┴──────────┴──────────────┴───┴────────────┴──────────┴───────────┴───────────┘
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬────────────┬──────────┬───────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX    ┆ LINREFY  ┆ latitude  ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---        ┆ ---      ┆ ---       ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64        ┆ f64      ┆ f64       ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪════════════╪══════════╪═══════════╪═══════════╡
# │ 1     ┆ 0      ┆ 53       ┆ 120          ┆ … ┆ 606982.394 ┆ 5.9547e6 ┆ 53.729615 ┆ 10.621659 │
# └───────┴────────┴──────────┴──────────────┴───┴────────────┴──────────┴───────────┴───────────┘
# shape: (1, 21)
# ┌───────┬────────┬──────────┬──────────────┬───┬─────────────┬──────────┬───────────┬───────────┐
# │ state ┆ region ┆ district ┆ municipality ┆ … ┆ LINREFX     ┆ LINREFY  ┆ latitude  ┆ longitude │
# │ ---   ┆ ---    ┆ ---      ┆ ---          ┆   ┆ ---         ┆ ---      ┆ ---       ┆ ---       │
# │ i64   ┆ i64    ┆ i64      ┆ i64          ┆   ┆ f64         ┆ f64      ┆ f64       ┆ f64       │
# ╞═══════╪════════╪══════════╪══════════════╪═══╪═════════════╪══════════╪═══════════╪═══════════╡
# │ 12    ┆ 0      ┆ 68       ┆ 468          ┆ … ┆ 735840.4367 ┆ 5.8872e6 ┆ 53.082133 ┆ 12.521519 │
# └───────┴────────┴──────────┴──────────────┴───┴─────────────┴──────────┴───────────┴───────────┘

# %%
# get all accidents with bicycle involvement is_bicycle	== 1
bicycle_accidents = pl.concat(acc_frames)
bicycle_accidents = bicycle_accidents.filter(pl.col('is_bicycle') == 1)

# %%
# choose heidelberg: state=8, region=2, district=21
state = 8
region = 2
district = 21
bicycle_accidents_hdb = bicycle_accidents.filter(
    (pl.col('state') == state) &
    (pl.col('region') == region) &
    (pl.col('district') == district)
)

# %%
#check the mean location of the accidents in heidelberg
bicycle_accidents_hdb.select(['latitude', 'longitude']).mean().to_numpy()[0].tolist()
# Out:
# [49.40615652129418, 8.683069257318808]

# %%
# Create a color map for the years
min_acc_year = bicycle_accidents_hdb['year'].min()
max_acc_year = bicycle_accidents_hdb['year'].max()
num_years = max_acc_year - min_acc_year + 1

# Use a colormap for the years
cmap = plt.colormaps['viridis'] 
year_colors = {year: mcolors.rgb2hex(cmap(i / (num_years - 1))) for i, year in enumerate(range(min_acc_year, max_acc_year + 1))}

m2 = folium.Map(location=[49.398752, 8.672434], zoom_start=13)

for row in bicycle_accidents_hdb.iter_rows(named=True):
    year = row['year']
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=5,
        popup=f"Year: {year}, Month: {row['month']}",
        color=year_colors[year],
        fill=True,
        fill_color=year_colors[year],
        fill_opacity=0.7
    ).add_to(m2)

# just for a simple legend
legend_html = '''
     <div style="position: fixed; 
                 bottom: 50px; left: 50px; width: 150px; height: 220px; 
                 border:2px solid grey; z-index:9999; font-size:14px;
                 background-color:white; padding: 10px;">
     <b>Accident Years</b><br>
'''
for year in range(min_acc_year, max_acc_year + 1):
    color = year_colors[year]
    legend_html += f'<i style="background:{color};width:10px;height:10px;float:left;margin-right:5px;"></i>{year}<br>'
legend_html += '</div>'

m2.get_root().html.add_child(folium.Element(legend_html))

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f9ce0c5c012677456660a64a15b3a14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;div style=&quot;position: fixed;
#                  bottom: 50px; left: 50px; width: 150px; height: 220px;
#                  border:2px solid grey; z-index:9999; font-size:14px;
#                  background-color:white; padding: 10px;&quot;&gt;
#      &lt;b&gt;Accident Years&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:#440154;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2016&lt;br&gt;&lt;i style=&quot;background:#472d7b;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2017&lt;br&gt;&lt;i style=&quot;background:#3b528b;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2018&lt;br&gt;&lt;i style=&quot;background:#2c728e;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2019&lt;br&gt;&lt;i style=&quot;background:#21918c;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2020&lt;br&gt;&lt;i style=&quot;background:#28ae80;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2021&lt;br&gt;&lt;i style=&quot;background:#5ec962;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2022&lt;br&gt;&lt;i style=&quot;background:#addc30;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2023&lt;br&gt;&lt;i style=&quot;background:#fde725;width:10px;height:10px;float:left;margin-right:5px;&quot;&gt;&lt;/i&gt;2024&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f9ce0c5c012677456660a64a15b3a14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f9ce0c5c012677456660a64a15b3a14 = L.map(
#                 &quot;map_2f9ce0c5c012677456660a64a15b3a14&quot;,
#                 {
#                     center: [49.398752, 8.672434],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0524ecf83cb00a0eb31995174b031e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0524ecf83cb00a0eb31995174b031e2.addTo(map_2f9ce0c5c012677456660a64a15b3a14);
#
#
#             var circle_marker_31919b08eb34e3181c4c2afbbb5be7c1 = L.circleMarker(
#                 [49.40303130500007, 8.691848012000037],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2c728e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2c728e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2f9ce0c5c012677456660a64a15b3a14);
#
#
#         var popup_2b4e4926c79875a478a4fa879e3d998f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d47d2bada9f9aff460524622a94c1b8 = $(`&lt;div id=&quot;html_3d47d2bada9f9aff460524622a94c1b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year: 2019, Month: 1&lt;/div&gt;`)[0];
#                 popup_2b4e4926c79875a478a4fa879e3d998f.setContent(html_3d47d2bada9f9aff460524622a94c1b8);
#
#
#
#         circle_marker_31919b08eb34e3181c4c2afbbb5be7c1.bindPopup(popup_2b4e4926c79875a478a4fa879e3d998f)
#         ;
#
#
#
#
#             var circle_marker_fbc3047d54f0fc739581f41ae30311f3 = L.circleMarker(
#                 [49.43112492600005, 8.682498703000022],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2c728e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2c728e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2f9ce0c5c012677456660a64a15b3a14);
#
#
#         var popup_f9f43644e4bcc4f7d0a0edbcdf1c1d86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3730cdea335835898d39e2725f9967b = $(`&lt;div id=&quot;html_c3730cdea335835898d39e2725f9967b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year: 2019, Month: 1&lt;/div&gt;`)[0];
#                 popup_f9f43644e4bcc4f7d0a0edbcdf1c1d86.setContent(html_c3730cdea335835898d39e2725f9967b);

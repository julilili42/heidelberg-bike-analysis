# %%
import os
import folium
import matplotlib as plt
import matplotlib.colors as mcolors
import seaborn as sns
import polars as pl
from data_io.loader.data_loader import DataLoader

# %%
dl = DataLoader()

# Heidelberg
acc = (
    dl.accident_data
    .bicycle_only()
    .filter_region(state=8, region=2, district=21)
)

points = acc.map_points()

# %%
years = sorted(acc.df["year"].unique().to_list())
cmap = plt.colormaps['viridis']
year_colors = {
    year: mcolors.rgb2hex(cmap(i / (len(years)-1)))
    for i, year in enumerate(years)
}

# %%
center = acc.df.select(["latitude", "longitude"]).mean().to_numpy()[0].tolist()

m = folium.Map(location=center, zoom_start=13)

for lat, lon, year, month in points:
    folium.CircleMarker(
        location=[lat, lon],
        radius=5,
        popup=f"Year: {year}, Month: {month}",
        color=year_colors[year],
        fill=True,
        fill_color=year_colors[year],
        fill_opacity=0.7
    ).add_to(m)

legend_html = '''
     <div style="
         position: fixed;
         bottom: 50px;
         left: 50px;
         width: 150px;
         height: auto;
         border: 2px solid grey;
         z-index: 9999;
         background-color: white;
         padding: 10px;
         font-size: 14px;
     ">
     <b>Accident Years</b><br>
'''

for year in years:
    color = year_colors[year]
    legend_html += f'''
        <i style="
            background:{color};
            width:12px;
            height:12px;
            float:left;
            margin-right:6px;
            opacity:0.9;
        "></i>{year}<br>
    '''

legend_html += "</div>"

m.get_root().html.add_child(folium.Element(legend_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa5aca00226e15995e224ed659d78317 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;div style=&quot;
#          position: fixed;
#          bottom: 50px;
#          left: 50px;
#          width: 150px;
#          height: auto;
#          border: 2px solid grey;
#          z-index: 9999;
#          background-color: white;
#          padding: 10px;
#          font-size: 14px;
#      &quot;&gt;
#      &lt;b&gt;Accident Years&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#440154;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2016&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#472d7b;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2017&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#3b528b;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2018&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#2c728e;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2019&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#21918c;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2020&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#28ae80;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2021&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#5ec962;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2022&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#addc30;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2023&lt;br&gt;
#
#         &lt;i style=&quot;
#             background:#fde725;
#             width:12px;
#             height:12px;
#             float:left;
#             margin-right:6px;
#             opacity:0.9;
#         &quot;&gt;&lt;/i&gt;2024&lt;br&gt;
#     &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa5aca00226e15995e224ed659d78317&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa5aca00226e15995e224ed659d78317 = L.map(
#                 &quot;map_aa5aca00226e15995e224ed659d78317&quot;,
#                 {
#                     center: [49.40615652129419, 8.683069257318806],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3d6fdd271c9ec1ab5dad601fe82b54e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3d6fdd271c9ec1ab5dad601fe82b54e.addTo(map_aa5aca00226e15995e224ed659d78317);
#
#
#             var circle_marker_248d7a68cc9214a8ac0cc2feecd6e29a = L.circleMarker(
#                 [49.420853201, 8.689431382],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#440154&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa5aca00226e15995e224ed659d78317);
#
#
#         var popup_d6df6e6072f9bad06e1aef00b7a5f73d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77c8dd6da7e17037adad0d441d8505dd = $(`&lt;div id=&quot;html_77c8dd6da7e17037adad0d441d8505dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year: 2016, Month: 1&lt;/div&gt;`)[0];
#                 popup_d6df6e6072f9bad06e1aef00b7a5f73d.setContent(html_77c8dd6da7e17037adad0d441d8505dd);
#
#
#
#         circle_marker_248d7a68cc9214a8ac0cc2feecd6e29a.bindPopup(popup_d6df6e6072f9bad06e1aef00b7a5f73d)
#         ;
#
#
#
#
#             var circle_marker_512eb8a0aa26ea2ac1abf8318831966a = L.circleMarker(
